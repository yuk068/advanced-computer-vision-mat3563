# %%
import os

import matplotlib
matplotlib.use('AGG')

import matplotlib.pyplot as plt
import numpy as np

import keras

from keras.datasets import cifar10
from keras.layers import (Activation, Conv3D, Dense, Dropout, Flatten,
                          MaxPooling3D, MaxPooling2D)

from keras.layers import LeakyReLU
from keras.losses import categorical_crossentropy
from keras.models import Sequential
from keras.optimizers import Adam
#from keras.utils import np_utils
#from keras.utils.vis_utils import plot_model
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split

#import videoto3d
from tqdm import tqdm

from keras.callbacks import ModelCheckpoint
from keras.models import Model
from keras.layers import Input, Dense

##
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
#from keras.backend.tensorflow_backend import set_session

# %%
import cv2


class Videoto3D:

    def __init__(self, width, height, depth):
        self.width = width
        self.height = height
        self.depth = depth

    def video3d(self, filename, color=False, skip=True):
        
        cap = cv2.VideoCapture(filename)
        
        nframe = cap.get(cv2.CAP_PROP_FRAME_COUNT)
        
        if skip:
            frames = [x * nframe / self.depth for x in range(self.depth)]
        else:
            frames = [x for x in range(self.depth)]
        
        framearray = []

        for i in range(self.depth):
            cap.set(cv2.CAP_PROP_POS_FRAMES, frames[i])
            ret, frame = cap.read()
        
            frame = cv2.resize(frame, (self.height, self.width))
        
            if color:
                framearray.append(frame)
            else:
                framearray.append(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))

        cap.release()
        
        return np.array(framearray)

    def get_UCF_classname(self, filename):
        x =  filename[filename.find('_') + 1:filename.find('_', 2)]
        print(x)
        return x

# %%
def plot_history(history, result_dir):
    plt.plot(history.history['accuracy'], marker='.')
    plt.plot(history.history['val_accuracy'], marker='.')
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['accuracy', 'val_accuracy'], loc='lower right')
    plt.savefig(os.path.join(result_dir, 'model_accuracy.png'))
    plt.close()

    plt.plot(history.history['loss'], marker='.')
    plt.plot(history.history['val_loss'], marker='.')
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend(['loss', 'val_loss'], loc='upper right')
    plt.savefig(os.path.join(result_dir, 'model_loss.png'))
    plt.close()


def save_history(history, result_dir):
    loss = history.history['loss']
    acc = history.history['accuracy']
    val_loss = history.history['val_loss']
    val_acc = history.history['val_accuracy']
    nb_epoch = len(acc)

    with open(os.path.join(result_dir, 'result.txt'), 'w') as fp:
        fp.write('epoch\tloss\tacc\tval_loss\tval_acc\n')
        for i in range(nb_epoch):
            fp.write('{}\t{}\t{}\t{}\t{}\n'.format(
                i, loss[i], acc[i], val_loss[i], val_acc[i]))
    


def loaddata(video_dir, vid3d, nclass, result_dir, color=False, skip=True):
    
    files = os.listdir(video_dir)    
    X = []
    labels = []
    labellist = []

    pbar = tqdm(total=len(files))

    for filename in files:
    
        pbar.update(1)
        
        if filename == '.DS_Store':
            continue
        
        name = os.path.join(video_dir, filename)

        for v_files in os.listdir(name):

            v_file_path = os.path.join(name, v_files)

            label = vid3d.get_UCF_classname(filename)
            
            if label not in labellist:
                
                if len(labellist) >= nclass:
                    continue

                labellist.append(label)
            
            labels.append(label)
            
            X.append(vid3d.video3d(v_file_path, color=color, skip=skip))

    pbar.close()

    with open(os.path.join(result_dir, 'classes.txt'), 'w') as fp:
        for i in range(len(labellist)):
            fp.write('{}\n'.format(labellist[i]))

    for num, label in enumerate(labellist):
        for i in range(len(labels)):
            if label == labels[i]:
                labels[i] = num
                
    if color:
        return np.array(X).transpose((0, 2, 3, 4, 1)), labels
    else:
        return np.array(X).transpose((0, 2, 3, 1)), labels

# %%
def main():

    print('simple 3D convolution for action recognition')
    batch = 128
    # training epoch
    epoch = 100
    # directory where videos are stored
    videos= 'UCF50'
    # Number of classes
    nclass = 50
    output = 'results'
    color  = False
    skip   = True
    depth  = 10

    
    img_rows, img_cols, frames = 32, 32, depth
    channel = 3 if color else 1
    fname_npz = 'dataset_{}_{}_{}.npz'.format(nclass, depth, skip)

    vid3d = Videoto3D(img_rows, img_cols, frames)
    nb_classes = nclass
    if os.path.exists(fname_npz):
        loadeddata = np.load(fname_npz)
        X, Y = loadeddata["X"], loadeddata["Y"]
    else:
        x, y = loaddata(videos, vid3d, nclass,
                        output, color, skip)
        X = x.reshape((x.shape[0], img_rows, img_cols, frames, channel))
        Y = keras.utils.to_categorical(y, nb_classes)

        X = X.astype('float32')
        np.savez(fname_npz, X=X, Y=Y)
        print('Saved dataset to dataset.npz.')
    print('X_shape:{}\nY_shape:{}'.format(X.shape, Y.shape))

    # Define model
    # model = Sequential()


    # model.add(Conv3D(16, kernel_size=(3, 3, 3), input_shape=(
    #     X.shape[1:]), padding='same'))
    # model.add(LeakyReLU(alpha=.001)) 


    # model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
    #     X.shape[1:]), padding='same'))
    # model.add(LeakyReLU(alpha=.001)) 

    ###########################

    input_x = Input(shape = (32, 32, depth, 1))

    initial_conv = Conv3D(16, kernel_size= (3, 3, 3), padding='same')(input_x)
    initial_conv = LeakyReLU(alpha=.001)(initial_conv)

    initial_conv = Conv3D(32, kernel_size= (3, 3, 3), padding='same')(initial_conv)
    initial_conv = LeakyReLU(alpha=.001)(initial_conv)


    ###########################
    # PARALLEL 1

    conv1 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(initial_conv)
    conv1 = LeakyReLU(alpha=.001)(conv1)
    conv1 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv1)


    # conv1 = Conv3D(16, kernel_size=(3, 3, 3),padding='same')(conv1)
    # conv1 = LeakyReLU(alpha=.001)(conv1)

    conv1 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv1)
    conv1 = LeakyReLU(alpha=.001)(conv1)

    
    conv1 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv1)

    # conv1 = Conv3D(8, kernel_size=(1, 1, 1),padding='same')(conv1)

    #check it    
    # conv1 = LeakyReLU(alpha=.001)(conv1)

    # conv1 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv1)

    ##############################

    ##############################

    #Parallel 2

    conv2 = Conv3D(8, kernel_size=(1, 1, 1),padding='same')(initial_conv)
    conv2 = LeakyReLU(alpha=.001)(conv2)
    conv2 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv2)


    # conv2 = Conv3D(8, kernel_size=(3, 3, 3),padding='same')(conv2)
    # conv2 = LeakyReLU(alpha=.001)(conv2)

    conv2 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv2)
    conv2 = LeakyReLU(alpha=.001)(conv2)
    

    conv2 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv2)

    # conv2 = Conv3D(4, kernel_size=(1, 1, 1),padding='same')(conv2)

    # #check it    
    # conv2 = LeakyReLU(alpha=.001)(conv2)

    # conv2 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv2)

    ###################################


    ##############################

    #Parallel 3

    conv3 = Conv3D(4, kernel_size=(1, 1, 1),padding='same')(initial_conv)
    conv3 = LeakyReLU(alpha=.001)(conv3)
    conv3 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv3)


    # conv3 = Conv3D(4, kernel_size=(3, 3, 3),padding='same')(conv3)
    # conv3 = LeakyReLU(alpha=.001)(conv3)

    conv3 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv3)
    conv3 = LeakyReLU(alpha=.001)(conv3)
    

    conv3 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv3)

    # conv3 = Conv3D(4, kernel_size=(1, 1, 1),padding='same')(conv3)

    # #check it    
    # conv3 = LeakyReLU(alpha=.001)(conv3)

    # conv3 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv3)

    ###################################

    added = keras.layers.Add()([conv1, conv2, conv3])

    added = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(added)

    added = Flatten()(added)

    dense_1 = Dense(256)(added)

    dense_2 = Dense(nb_classes, activation = 'softmax')(dense_1)

    model = Model(input_x, dense_2)

    model.compile(loss=categorical_crossentropy,
                  optimizer=Adam(), metrics=['accuracy']) 

    model.summary()
    # plot_model(model, show_shapes=True,
    #            to_file=os.path.join(args.output, 'model.png'))

    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=0.2, random_state=43)
    print(X_train.shape)

    ####################

    # 1
    filepath="d_3dcnnmodel-{epoch:02d}-{val_accuracy:.2f}.weights.hd5.keras"
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    callbacks_list = [checkpoint]

    # 2 

    config = tf.compat.v1.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.3
    set_session(tf.compat.v1.Session(config=config))

    ###############

    # Train model
    history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size=batch,
                        epochs=epoch, verbose=1, shuffle=True, callbacks=callbacks_list)
    
    model.evaluate(X_test, Y_test, verbose=0)
    
    model_json = model.to_json()
    
    if not os.path.isdir(output):
        os.makedirs(output)
    with open(os.path.join(output, 'ucf50_3dcnnmodel.json'), 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights(os.path.join(output, 'ucf50_3dcnnmodel-gpu.weights.h5'))

    loss, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test loss:', loss)
    print('Test accuracy:', acc)

    plot_history(history, output)
    save_history(history, output)

# %%
os.chdir('D:\\Teach_n_Train\\Advanced_Lessons_CV\\LABS\\CV_3D_Data\\simple3D') 
if __name__ == '__main__':
    main()
# Out:
# simple 3D convolution for action recognition
# X_shape:(6681, 32, 32, 10, 1)
# Y_shape:(6681, 50)
# C:\Users\WinIF Chung\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 32, 32, 10, 1)     │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3d (Conv3D)               │ (None, 32, 32, 10, 16)    │             448 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 32, 10, 16)    │               0 │ conv3d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3d_1 (Conv3D)             │ (None, 32, 32, 10, 32)    │          13,856 │ leaky_re_lu[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 32, 10, 32)    │               0 │ conv3d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3d_2 (Conv3D)             │ (None, 32, 32, 10, 16)    │             528 │ leaky_re_lu_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3d_4 (Conv3D)             │ (None, 32, 32, 10, 8)     │             264 │ leaky_re_lu_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3d_6 (Conv3D)             │ (None, 32, 32, 10, 4)     │             132 │ leaky_re_lu_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 32, 10, 16)    │               0 │ conv3d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 32, 32, 10, 8)     │               0 │ conv3d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 32, 32, 10, 4)     │               0 │ conv3d_6[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling3d (MaxPooling3D)  │ (None, 16, 16, 5, 16)     │               0 │ leaky_re_lu_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling3d_2               │ (None, 16, 16, 5, 8)      │               0 │ leaky_re_lu_4[0][0]        │
# │ (MaxPooling3D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling3d_4               │ (None, 16, 16, 5, 4)      │               0 │ leaky_re_lu_6[0][0]        │
# │ (MaxPooling3D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3d_3 (Conv3D)             │ (None, 16, 16, 5, 16)     │             272 │ max_pooling3d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3d_5 (Conv3D)             │ (None, 16, 16, 5, 16)     │             144 │ max_pooling3d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv3d_7 (Conv3D)             │ (None, 16, 16, 5, 16)     │              80 │ max_pooling3d_4[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 16, 5, 16)     │               0 │ conv3d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 16, 5, 16)     │               0 │ conv3d_5[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 16, 16, 5, 16)     │               0 │ conv3d_7[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling3d_1               │ (None, 8, 8, 3, 16)       │               0 │ leaky_re_lu_3[0][0]        │
# │ (MaxPooling3D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling3d_3               │ (None, 8, 8, 3, 16)       │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling3D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling3d_5               │ (None, 8, 8, 3, 16)       │               0 │ leaky_re_lu_7[0][0]        │
# │ (MaxPooling3D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 8, 8, 3, 16)       │               0 │ max_pooling3d_1[0][0],     │
# │                               │                           │                 │ max_pooling3d_3[0][0],     │
# │                               │                           │                 │ max_pooling3d_5[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling3d_6               │ (None, 4, 4, 2, 16)       │               0 │ add[0][0]                  │
# │ (MaxPooling3D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 512)               │               0 │ max_pooling3d_6[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 256)               │         131,328 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 50)                │          12,850 │ dense[0][0]                │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 159,902 (624.62 KB)
#  Trainable params: 159,902 (624.62 KB)
#  Non-trainable params: 0 (0.00 B)
# (5344, 32, 32, 10, 1)
# WARNING:tensorflow:From C:\Users\WinIF Chung\AppData\Local\Temp\ipykernel_17116\2605031103.py:176: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 628ms/step - accuracy: 0.0219 - loss: 28.6787
# Epoch 1: val_accuracy improved from -inf to 0.03441, saving model to d_3dcnnmodel-01-0.03.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 670ms/step - accuracy: 0.0221 - loss: 28.3432 - val_accuracy: 0.0344 - val_loss: 4.3547
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 626ms/step - accuracy: 0.0420 - loss: 4.0996
# Epoch 2: val_accuracy improved from 0.03441 to 0.04562, saving model to d_3dcnnmodel-02-0.05.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 663ms/step - accuracy: 0.0422 - loss: 4.0964 - val_accuracy: 0.0456 - val_loss: 3.8504
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.0767 - loss: 3.7450
# Epoch 3: val_accuracy improved from 0.04562 to 0.07330, saving model to d_3dcnnmodel-03-0.07.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 652ms/step - accuracy: 0.0769 - loss: 3.7442 - val_accuracy: 0.0733 - val_loss: 3.7369
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.1036 - loss: 3.5957
# Epoch 4: val_accuracy improved from 0.07330 to 0.09798, saving model to d_3dcnnmodel-04-0.10.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 650ms/step - accuracy: 0.1037 - loss: 3.5950 - val_accuracy: 0.0980 - val_loss: 3.6181
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.1353 - loss: 3.4141
# Epoch 5: val_accuracy improved from 0.09798 to 0.13987, saving model to d_3dcnnmodel-05-0.14.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 675ms/step - accuracy: 0.1356 - loss: 3.4128 - val_accuracy: 0.1399 - val_loss: 3.4514
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.1822 - loss: 3.1552
# Epoch 6: val_accuracy improved from 0.13987 to 0.15557, saving model to d_3dcnnmodel-06-0.16.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 647ms/step - accuracy: 0.1822 - loss: 3.1550 - val_accuracy: 0.1556 - val_loss: 3.3395
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - accuracy: 0.2278 - loss: 2.9579
# Epoch 7: val_accuracy improved from 0.15557 to 0.18848, saving model to d_3dcnnmodel-07-0.19.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 639ms/step - accuracy: 0.2279 - loss: 2.9571 - val_accuracy: 0.1885 - val_loss: 3.1679
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.2887 - loss: 2.7473
# Epoch 8: val_accuracy improved from 0.18848 to 0.20718, saving model to d_3dcnnmodel-08-0.21.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 646ms/step - accuracy: 0.2886 - loss: 2.7474 - val_accuracy: 0.2072 - val_loss: 3.0472
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.3211 - loss: 2.5754
# Epoch 9: val_accuracy improved from 0.20718 to 0.23710, saving model to d_3dcnnmodel-09-0.24.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 641ms/step - accuracy: 0.3213 - loss: 2.5746 - val_accuracy: 0.2371 - val_loss: 2.9334
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.3737 - loss: 2.3570
# Epoch 10: val_accuracy improved from 0.23710 to 0.26627, saving model to d_3dcnnmodel-10-0.27.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 640ms/step - accuracy: 0.3737 - loss: 2.3571 - val_accuracy: 0.2663 - val_loss: 2.8848
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.4135 - loss: 2.2149
# Epoch 11: val_accuracy improved from 0.26627 to 0.28796, saving model to d_3dcnnmodel-11-0.29.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 642ms/step - accuracy: 0.4134 - loss: 2.2147 - val_accuracy: 0.2880 - val_loss: 2.7707
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.4511 - loss: 2.0488
# Epoch 12: val_accuracy improved from 0.28796 to 0.31339, saving model to d_3dcnnmodel-12-0.31.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 642ms/step - accuracy: 0.4512 - loss: 2.0480 - val_accuracy: 0.3134 - val_loss: 2.6477
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.4776 - loss: 1.9292
# Epoch 13: val_accuracy improved from 0.31339 to 0.31788, saving model to d_3dcnnmodel-13-0.32.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 643ms/step - accuracy: 0.4777 - loss: 1.9284 - val_accuracy: 0.3179 - val_loss: 2.5725
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.5241 - loss: 1.7233
# Epoch 14: val_accuracy improved from 0.31788 to 0.35079, saving model to d_3dcnnmodel-14-0.35.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 651ms/step - accuracy: 0.9747 - loss: 0.1118 - val_accuracy: 0.4921 - val_loss: 3.0768
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 616ms/step - accuracy: 0.9626 - loss: 0.1481
# Epoch 42: val_accuracy did not improve from 0.49364
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 651ms/step - accuracy: 0.9625 - loss: 0.1482 - val_accuracy: 0.4907 - val_loss: 3.0220
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - accuracy: 0.9799 - loss: 0.0963
# Epoch 43: val_accuracy did not improve from 0.49364
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 650ms/step - accuracy: 0.9800 - loss: 0.0961 - val_accuracy: 0.4839 - val_loss: 3.1601
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.9886 - loss: 0.0694
# Epoch 44: val_accuracy improved from 0.49364 to 0.50636, saving model to d_3dcnnmodel-44-0.51.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 653ms/step - accuracy: 0.9886 - loss: 0.0695 - val_accuracy: 0.5064 - val_loss: 3.1227
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.9946 - loss: 0.0538
# Epoch 45: val_accuracy did not improve from 0.50636
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 651ms/step - accuracy: 0.9946 - loss: 0.0538 - val_accuracy: 0.5004 - val_loss: 3.2130
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.9979 - loss: 0.0361
# Epoch 46: val_accuracy improved from 0.50636 to 0.50785, saving model to d_3dcnnmodel-46-0.51.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 654ms/step - accuracy: 0.9979 - loss: 0.0360 - val_accuracy: 0.5079 - val_loss: 3.1540
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.9989 - loss: 0.0245
# Epoch 47: val_accuracy improved from 0.50785 to 0.50860, saving model to d_3dcnnmodel-47-0.51.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 650ms/step - accuracy: 0.9989 - loss: 0.0245 - val_accuracy: 0.5086 - val_loss: 3.1710
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 48: val_accuracy did not improve from 0.50860
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 648ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.5071 - val_loss: 3.2642
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 616ms/step - accuracy: 1.0000 - loss: 0.0150
# Epoch 49: val_accuracy improved from 0.50860 to 0.51758, saving model to d_3dcnnmodel-49-0.52.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 653ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.5176 - val_loss: 3.2868
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 50: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 658ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.5138 - val_loss: 3.3248
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 51: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 658ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.5041 - val_loss: 3.3625
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 52: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 658ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.5161 - val_loss: 3.3963
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 53: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 657ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.5108 - val_loss: 3.3970
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 54: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 656ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.5093 - val_loss: 3.4338
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 55: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 655ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.5079 - val_loss: 3.4680
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 56: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 659ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.5071 - val_loss: 3.5086
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 624ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 57: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 660ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.5153 - val_loss: 3.5129
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 58: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 662ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.5153 - val_loss: 3.5294
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 59: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 668ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.5146 - val_loss: 3.5628
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 624ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 60: val_accuracy did not improve from 0.51758
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 658ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.5116 - val_loss: 3.5880
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 624ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch